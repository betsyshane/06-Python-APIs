# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv 
import json


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %%
# easier to just use city names
# with open('../city.list.json') as cities_file:
#     cityidlist = json.load(cities_file)

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
start = 1540944000
end = 1541030400

query_url = f"{url}appid={api_key}&type=hour&units={units}&q="

# cityid = []
newcity = []
cloud = []
country = []
date = []
humid = []
lat = []
lng = []
temp = []
wind = []

query_url = f"{url}appid={api_key}&type=hour&units={units}&start={start}&end={end}&q="

record = 0

cities_1 = []
cities_2 = []
cities_3 = []
cities_4 = []
cities_5 = []
cities_6 = []
cities_7 = []
cities_8 = []
cities_9 = []
cities_10 = []
cities_11 = []
cities_12 = []
cities_13 = []


for city in cities[0:50]:
    cities_1.append(city)

for city in cities[50:100]:
    cities_2.append(city)
    
for city in cities[100:150]:
    cities_3.append(city)

for city in cities[150:200]:
    cities_4.append(city)
    
for city in cities[200:250]:
    cities_5.append(city)
    
for city in cities[250:300]:
    cities_6.append(city)
    
for city in cities[300:350]:
    cities_7.append(city)    

for city in cities[350:400]:
    cities_8.append(city)    

for city in cities[400:450]:
    cities_9.append(city)    

for city in cities[450:500]:
    cities_10.append(city)
    
for city in cities[500:550]:
    cities_11.append(city)    

for city in cities[550:600]:
    cities_12.append(city)    

for city in cities[600:]:
    cities_13.append(city)    
    
set = 1    
for city in cities_1:
    try:
        response = requests.get(query_url + city).json()
        newcity.append(response['name'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humid.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        record = record + 1
        print(f"Processing Record {record} of Set {set} | {city}")
    except KeyError:
        print("Data not found. Skipping...")
        
record = 0        
time.sleep(60)

set = 2
for city in cities_2:
    try:
        response = requests.get(query_url + city).json()
        newcity.append(response['name'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humid.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        record = record + 1
        print(f"Processing Record {record} of Set {set} | {city}")
    except KeyError:
        print("Data not found. Skipping...")

time.sleep(60)
record = 0   
set = 3
for city in cities_3:
    try:
        response = requests.get(query_url + city).json()
        newcity.append(response['name'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humid.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        record = record + 1
        print(f"Processing Record {record} of Set {set} | {city}")
    except KeyError:
        print("Data not found. Skipping...")

time.sleep(60)
record = 0   
set = 4
for city in cities_4:
    try:
        response = requests.get(query_url + city).json()
        newcity.append(response['name'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humid.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        record = record + 1
        print(f"Processing Record {record} of Set {set} | {city}")
    except KeyError:
        print("Data not found. Skipping...")
time.sleep(60)
record = 0   
set = 5
for city in cities_5:
    try:
        response = requests.get(query_url + city).json()
        newcity.append(response['name'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humid.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        record = record + 1
        print(f"Processing Record {record} of Set {set} | {city}")
    except KeyError:
        print("Data not found. Skipping...")
time.sleep(60)
record = 0   
set = 6
for city in cities_6:
    try:
        response = requests.get(query_url + city).json()
        newcity.append(response['name'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humid.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        record = record + 1
        print(f"Processing Record {record} of Set {set} | {city}")
    except KeyError:
        print("Data not found. Skipping...")

time.sleep(60)
record = 0   
set = 7
for city in cities_7:
    try:
        response = requests.get(query_url + city).json()
        newcity.append(response['name'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humid.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        record = record + 1
        print(f"Processing Record {record} of Set {set} | {city}")
    except KeyError:
        print("Data not found. Skipping...")
time.sleep(60)
record = 0   
set = 8
for city in cities_8:
    try:
        response = requests.get(query_url + city).json()
        newcity.append(response['name'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humid.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        record = record + 1
        print(f"Processing Record {record} of Set {set} | {city}")
    except KeyError:
        print("Data not found. Skipping...")
        
time.sleep(60)
set = 9
record = 0   
for city in cities_9:
    try:
        response = requests.get(query_url + city).json()
        newcity.append(response['name'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humid.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        record = record + 1
        print(f"Processing Record {record} of Set {set} | {city}")
    except KeyError:
        print("Data not found. Skipping...")
time.sleep(60)
record = 0   
set = 10
for city in cities_10:
    try:
        response = requests.get(query_url + city).json()
        newcity.append(response['name'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humid.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        record = record + 1
        print(f"Processing Record {record} of Set {set} | {city}")
    except KeyError:
        print("Data not found. Skipping...")

time.sleep(60)
record = 0   
set = 11
for city in cities_11:
    try:
        response = requests.get(query_url + city).json()
        newcity.append(response['name'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humid.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        record = record + 1
        print(f"Processing Record {record} of Set {set} | {city}")
    except KeyError:
        print("Data not found. Skipping...")

time.sleep(60)
record = 0   
set = 12
for city in cities_12:
    try:
        response = requests.get(query_url + city).json()
        newcity.append(response['name'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humid.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        record = record + 1
        print(f"Processing Record {record} of Set {set} | {city}")
    except KeyError:
        print("Data not found. Skipping...")

time.sleep(60)
set = 13
record = 0   
for city in cities_13:
    try:
        response = requests.get(query_url + city).json()
        newcity.append(response['name'])
        cloud.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humid.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        record = record + 1
        print(f"Processing Record {record} of Set {set} | {city}")
    except KeyError:
        print("Data not found. Skipping...")

print("----Data Retrieval Complete-----")
# Out:
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | kavieng
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | bethel
# Processing Record 10 of Set 1 | hasaki
# Data not found. Skipping...
# Data not found. Skipping...
# Processing Record 11 of Set 1 | mandera
# Processing Record 12 of Set 1 | qaanaaq
# Data not found. Skipping...
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | upernavik
# Processing Record 19 of Set 1 | udachnyy
# Processing Record 20 of Set 1 | sao joao da barra
# Processing Record 21 of Set 1 | touros
# ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lompoc
# Processing Record 2 of Set 1 | klaksvik
# Processing Record 3 of Set 1 | bisignano
# Processing Record 4 of Set 1 | bengkulu
# City not found. Skipping...
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | ahipara
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | hamilton
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | ashland
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | haines junction
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | salalah
# Processing Record 16 of Set 1 | port macquarie
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | kaitangata
# Processing Record 20 of Set 1 | souillac
# Processing Record 21 of Set 1 | srednekolymsk
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
rawdata = {
    "City": newcity,
    "Cloudiness": cloud,
    "Country": country,
    "Date": date,
    "Humidity": humid,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": temp,
    "Wind Speed": wind
}


weather_data = pd.DataFrame(rawdata)
weather_data.count()
# Out:
# City          550
# Cloudiness    550
# Country       550
# Date          550
# Humidity      550
# Lat           550
# Lng           550
# Max Temp      550
# Wind Speed    550
# dtype: int64

# %%
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
weather_data.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  East London           0      ZA  1547438400        72 -33.02   27.91
# 1       Atuona         100      PF  1547440033       100  -9.80 -139.03
# 2        Kapaa          90      US  1547438640        68  22.08 -159.32
# 3     Thompson           5      CA  1547438400        70  55.74  -97.86
# 4      Rikitea          88      PF  1547440029        97 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     66.20        5.82
# 1     81.28       14.70
# 2     77.00        5.82
# 3     -0.41        5.82
# 4     80.20       12.46

# %%
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     lompoc           1      US  1534984500        44  34.64 -120.46
# 1   klaksvik          92      FO  1534983600       100  62.23   -6.59
# 2  bisignano           0      IT  1534981800        88  39.50   16.27
# 3       hilo          90      US  1534984860        90  19.71 -155.08
# 4    rikitea           8      PF  1534986579       100 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     77.00       11.41
# 1     50.00       13.87
# 2     66.20        5.82
# 3     77.00        8.05
# 4     69.58       19.71

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lat, temp, marker="o", color="blue", edgecolors="black", alpha=.35)
plt.title("City Latitude vs Max Temperature (10/31/18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("latitudevstemp.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lat, humid, marker="o", color="blue", edgecolors="black", alpha=.35)
plt.title("City Latitude vs Humidity (10/31/18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("latitudevshumidity.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat, cloud, marker="o", color="blue", edgecolors="black", alpha=.35)
plt.title("City Latitude vs Cloudiness (10/31/18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("latitudevscloud.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat, wind, marker="o", color="blue", edgecolors="black", alpha=.35)
plt.title("City Latitude vs Wind Speed (10/31/18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("latitudevswind.png", bbox_inches="tight")
plt.show()
